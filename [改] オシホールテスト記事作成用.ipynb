# %%
# !pip install python-wordpress-xmlrpc
# Out:
# Collecting python-wordpress-xmlrpc
#   Using cached python_wordpress_xmlrpc-2.3-py3-none-any.whl
# Installing collected packages: python-wordpress-xmlrpc
# Successfully installed python-wordpress-xmlrpc-2.3

# %%
#①
import os
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.support.ui import Select
import urllib
from bs4 import BeautifulSoup
import re
import pyperclip
import csv
import codecs
import requests
import urllib.request as req
import openpyxl
import glob
from sklearn.datasets import  load_iris
import json
import time
import datetime
from datetime import datetime, date, timedelta
import numpy as np
from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']
import matplotlib.pyplot as plt
import pandas as pd
from dateutil.relativedelta import relativedelta
from PIL import Image, ImageDraw, ImageFont
from wordpress_xmlrpc import Client, WordPressPost
from wordpress_xmlrpc.compat import xmlrpc_client
from wordpress_xmlrpc.methods import media, posts
import time
from wordpress_xmlrpc import Client, WordPressPost
from wordpress_xmlrpc.methods.users import GetUserInfo
from wordpress_xmlrpc.methods.posts import GetPosts, NewPost
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pyperclip
print('ライブラリの読み込み完了')

def set_round(x):
    x = (round(x, 1))
    return x

def set_round_int(x):
    x = int(round(x, 0))
    return x
# Out:
# ライブラリの読み込み完了

# %%
#/Users/macbook/Downloads/20210322_ワンダーランド香椎Ⅱ.xlsx
pd.set_option('display.max_rows', 8)
#pd.set_option('display.max_rows', None)
import pandas as p

#ここは記入する
title_text_only = '20230213_スーパーDステーション飯塚店'
filename= r"C:\Users\mtdyu\Desktop\20230213_スーパーDステーション飯塚店.xlsx"

sheet_df = pd.read_excel(filename, usecols=[0, 1, 2,9])
display(sheet_df)
sheet_df.columns = ['台番', '機種', 'G数','差枚']
sheet_df['G数'] = sheet_df['G数'].astype(int)
sheet_df['差枚'] = sheet_df['差枚'].astype(int)
sheet_df['出率'] = (sheet_df['G数'] * 3 + sheet_df['差枚'])
sheet_df['出率'] = sheet_df['出率'] / (sheet_df['G数'] * 3) * 100
sheet_df = sheet_df.fillna(0)
sheet_df['出率'] =sheet_df['出率'].map(set_round)
sheet_df = sheet_df.reindex(columns=['機種', '台番', '差枚','G数','出率'])
df_a = ichiran_df = sheet_df
display(df_a)

kisyubetu_sheet_df = sheet_df.groupby(['機種']).mean()
kisyubetu_sheet_df['差枚'] = kisyubetu_sheet_df['差枚'].map(set_round_int)
kisyubetu_sheet_df['出率'] = kisyubetu_sheet_df['出率'].map(set_round)
kisyubetu_sheet_df['G数'] = kisyubetu_sheet_df['G数'].map(set_round_int)
kisyu_matome_df = kisyubetu_sheet_df = kisyubetu_sheet_df.drop('台番', axis=1)
kisyu_matome_df.reset_index(inplace=True, drop=False)
kisyubetu_sheet_df['台数'] = list(ichiran_df.groupby('機種').count()['台番'])
bariety_df = kisyubetu_sheet_df[kisyubetu_sheet_df['台数'] == 1]
kisyubetu_sheet_df = kisyubetu_sheet_df[kisyubetu_sheet_df['台数'] != 1]

kisyu_name_list = []

for kisyu_name in list(kisyubetu_sheet_df['機種']):
    #print(kisyu_name)
    df_b = ichiran_df.query('機種.str.contains(@kisyu_name)', engine='python')
    #display(df_b)
    win_rate_bunshi = 0
    for x in list(df_b['差枚']):
        if x > 0:
            win_rate_bunshi += 1
        else:
            pass
    kisyu_name_list.append(win_rate_bunshi)

kisyubetu_sheet_df['勝利台数'] = kisyu_name_list
kisyubetu_sheet_df['勝利台数'] = kisyubetu_sheet_df['勝利台数'].astype(str)
kisyubetu_sheet_df['台数'] = kisyubetu_sheet_df['台数'].astype(str)

kisyubetu_sheet_df['勝率'] = kisyubetu_sheet_df['勝利台数'] + '/' + kisyubetu_sheet_df['台数']
kisyubetu_sheet_df = kisyubetu_sheet_df.drop(['勝利台数','台数'], axis=1)
kisyubetu_sheet_df = kisyubetu_sheet_df.reindex(columns=['機種', '差枚','G数','勝率','出率'])
kisyubetu_sheet_df = kisyubetu_sheet_df.sort_values('差枚', ascending=False)
display(kisyubetu_sheet_df)
# Out:
#        台番         機種名    G数    差枚
# 0    1017      ニャル子さん  1785  -200
# 1    1018        このすば  1606 -1100
# 2    1019        このすば  1845  -900
# 3    1020        このすば  3504  -200
# ..    ...         ...   ...   ...
# 440  1458  ニューゲッターマウス  5526  2600
# 441  1459    ディスクアップ2  6734   200
# 442  1460    ディスクアップ2  7726  -600
# 443  1461        マッピー  4927 -1000
#
# [444 rows x 4 columns]
#              機種    台番    差枚    G数     出率
# 0        ニャル子さん  1017  -200  1785   96.3
# 1          このすば  1018 -1100  1606   77.2
# 2          このすば  1019  -900  1845   83.7
# 3          このすば  1020  -200  3504   98.1
# ..          ...   ...   ...   ...    ...
# 440  ニューゲッターマウス  1458  2600  5526  115.7
# 441    ディスクアップ2  1459   200  6734  101.0
# 442    ディスクアップ2  1460  -600  7726   97.4
# 443        マッピー  1461 -1000  4927   93.2
#
# [444 rows x 5 columns]
# <ipython-input-2-a0d697a1049b>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kisyubetu_sheet_df['勝利台数'] = kisyu_name_list
# <ipython-input-2-a0d697a1049b>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kisyubetu_sheet_df['勝利台数'] = kisyubetu_sheet_df['勝利台数'].astype(str)
# <ipython-input-2-a0d697a1049b>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kisyubetu_sheet_df['台数'] = kisyubetu_sheet_df['台数'].astype(str)
# <ipython-input-2-a0d697a1049b>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kisyubetu_sheet_df['勝率'] = kisyubetu_sheet_df['勝利台数'] + '/' + kisyubetu_sheet_df['台数']
#              機種    差枚    G数     勝率     出率
# 10  シンフォギア 勇気の歌  2950  8679    4/4  111.3
# 38       番長ZERO  2288  8880  13/16  108.2
# 21      バジリスク絆2  2050  6449    5/8  107.4
# 6        まどか前後編  1667  7036    1/3  104.2
# ..          ...   ...   ...    ...    ...
# 28       主役は銭形3 -1050  1226    0/2   71.5
# 1   FAIRY TAIL2 -1167  4781    0/3   90.8
# 31        戦国無双3 -1300  7349    1/3   94.6
# 2     MHWアイスボーン -2686  5983    0/7   84.2
#
# [43 rows x 5 columns]

# %%
#③実行する
import gspread
import json
#ServiceAccountCredentials：Googleの各サービスへアクセスできるservice変数を生成します。
from oauth2client.service_account import ServiceAccountCredentials 

#2つのAPIを記述しないとリフレッシュトークンを3600秒毎に発行し続けなければならない
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

#認証情報設定
#ダウンロードしたjsonファイル名をクレデンシャル変数に設定（秘密鍵、Pythonファイルから読み込みしやすい位置に置く）
credentials = ServiceAccountCredentials.from_json_keyfile_name(r"C:\Users\mtdyu\Desktop\記事作成用\twitteranalytics-jsonsercretkey.json", scope)


#OAuth2の資格情報を使用してGoogle APIにログインします。
gc = gspread.authorize(credentials)

workbook = gc.open_by_url('https://docs.google.com/spreadsheets/d/1LmkbYAJq2g684bjF-vumexLgKrFQNsF-dhsdTv33_Yk/edit#gid=0')
workbook.add_worksheet(title=title_text_only, rows=700, cols=6)
worksheet = workbook.worksheet(title_text_only)
# df = pd.DataFrame(worksheet.get_all_values())
# df.columns = list(df.loc[0, :])
# df.drop(0, inplace=True)
# df.reset_index(inplace=True)
# kisyu_convert_df = df
# display(kisyu_convert_df)

# %%
#df_a['G数'] = df_a['G数'].map(set_round)
sum_append_list = []
df_a['差枚'] = pd.to_numeric(df_a['差枚'], downcast='integer')
df_a['G数'] = pd.to_numeric(df_a['G数'], downcast='integer')
df_a = df_a.reset_index(drop=True)
for i in range(0,len(df_a)):
    #print(df_a[i:i+6].sum()['差枚'])
    sum_append_list.append(df_a[i:i+6].sum()['差枚'])
df_a['6行合計値'] = sum_append_list
#display(df_a.style.bar(align="mid",color=['#d65f5f', '#5fba7d']))
df_a = df_a.drop('6行合計値',axis=1)
#ここで出ている箇所を確認する

# %%
# 数字からアルファベットを返す関数
# 例：26→Z、27→AA、10000→NTP
def toAlpha(num):
    if num<=26:
        return chr(64+num)
    elif num%26==0:
        return toAlpha(num//26-1)+chr(90)
    else:
        return toAlpha(num//26)+chr(64+num%26)

col_lastnum = len(df_a.columns) # DataFrameの列数
row_lastnum = len(df_a.index)   # DataFrameの行数

cell_list = worksheet.range('A1:'+toAlpha(col_lastnum)+str(row_lastnum))
for cell in cell_list:
    val = df_a.iloc[cell.row-1][cell.col-1]
    cell.value = str(val)
    print(cell.value)
worksheet.update_cells(cell_list)
# Out:
# ニャル子さん
# 1017
# -200
# 1785
# 96.3
# このすば
# 1018
# -1100
# 1606
# 77.2
# このすば
# 1019
# -900
# 1845
# 83.7
# このすば
# 1020
# -200
# 3504
# 98.1
# このすば
# 1021
# 900
# 9170
# 103.3
# このすば
# 1022
# -1200
# 1781
# 77.5
# シンフォギア 勇気の歌
# 1023
# 4000
# 8959
# 114.9
# シンフォギア 勇気の歌
# 1024
# 1300
# 8799
# 104.9
# シンフォギア 勇気の歌
# 1025
# 3100
# 8186
# 112.6
# シンフォギア 勇気の歌
# 1026
# 3400
# 8771
# 112.9
# ドリフターズ
# 1027
# -900
# 1842
# 83.7
# ドリフターズ
# 1028
# 2200
# 9129
# 108.0
# ドリフターズ
# 1029
# -1200
# 3900
# 89.7
# まどか前後編
# 1030
# -700
# 3579
# 93.5
# まどか前後編
# 1031
# 6100
# 9733
# 120.9
# まどか前後編
# 1032
# -400
# 7797
# 98.3
# 戦国無双3
# 1033
# 1700
# 7023
# 108.1
# 戦国無双3
# 1034
# -1600
# 6921
# 92.3
# 戦国無双3
# 1035
# -4000
# 8103
# 83.5
# ダンまち外伝
# 1036
# 100
# 2926
# 101.1
# ダンまち外伝
# 1037
# 900
# 1754
# 117.1
# ダンまち外伝
# 1038
# -200
# 339
# 80.3
# 閃乱カグラBURST UP
# 1039
# 0
# 4425
# 100.0
# 閃乱カグラBURST UP
# 1040
# -500
# 791
# 78.9
# 北斗の拳 宿命
# 1041
# -700
# 1539
# 84.8
# 北斗の拳 宿命
# 1042
# 0
# 5037
# 100.0
# 主役は銭形3
# 1043
# -700
# 1213
# 80.8
# 主役は銭形3
# 1044
# -1400
# 1238
# 62.3
# 真俺の空
# 1045
# -100
# 3165
# 98.9
# 真俺の空
# 1046
# -500
# 327
# 49.0
# 真俺の空
# 1047
# 1100
# 9760
# 103.8
# 真俺の空
# 1048
# -100
# 560
# 94.0
# 真俺の空
# 1049
# -1200
# 1130
# 64.6
# 犬夜叉
# 1050
# -1100
# 933
# 60.7
# 犬夜叉
# 1051
# 4000
# 3051
# 143.7
# 犬夜叉
# 1052
# -800
# 851
# 68.7
# 犬夜叉
# 1053
# -200
# 1001
# 93.3
# 犬夜叉
# 1054
# -1200
# 3190
# 87.5
# 黄門ちゃま喝2
# 1055
# 1400
# 3392
# 113.8
# 黄門ちゃま喝2
# 1056
# -200
# 4056
# 98.4
# 黄門ちゃま喝2
# 1057
# -1600
# 1704
# 68.7
# 頭文字D
# 1058
# 2200
# 8491
# 108.6
# 頭文字D
# 1059
# -1300
# 2425
# 82.1
# 頭文字D
# 1060
# -1300
# 2846
# 84.8
# 緋弾のアリアⅡ
# 1061
# 2200
# 8716
# 108.4
# 緋弾のアリアⅡ
# 1062
# 1100
# 6046
# 106.1
# 緋弾のアリアⅡ
# 1063
# -900
# 5817
# 94.8
# 緋弾のアリアⅡ
# 1064
# 1000
# 4683
# 107.1
# とある科学の超電磁砲
# 1065
# 600
# 8646
# 102.3
# とある科学の超電磁砲
# 1066
# -2400
# 3135
# 74.5
# とある科学の超電磁砲
# 1067
# 6600
# 9717
# 122.6
# とある科学の超電磁砲
# 1068
# 1100
# 7723
# 104.7
# とある科学の超電磁砲
# 1069
# 1600
# 6674
# 108.0
# FAIRY TAIL2
# 1070
# -1000
# 6821
# 95.1
# FAIRY TAIL2
# 1071
# -1300
# 3316
# 86.9
# FAIRY TAIL2
# 1072
# -1200
# 4207
# 90.5
# アクエリオンALL STARS
# 1073
# -1100
# 1217
# 69.9
# アクエリオンALL STARS
# 1074
# -700
# 1937
# 88.0
# アクエリオンALL STARS
# 1075
# -200
# 465
# 85.7
# アクエリオンALL STARS
# 1076
# 200
# 5348
# 101.2
# MHWアイスボーン
# 1077
# -700
# 6468
# 96.4
# MHWアイスボーン
# 1078
# -3600
# 4754
# 74.8
# MHWアイスボーン
# 1079
# -2600
# 7156
# 87.9
# MHWアイスボーン
# 1080
# -3100
# 6023
# 82.8
# MHWアイスボーン
# 1081
# 甲鉄城のカバネリ
# 1129
# 1800
# 9610
# 106.2
# 甲鉄城のカバネリ
# 1130
# -1500
# 2954
# 83.1
# 甲鉄城のカバネリ
# 1131
# 1900
# 6426
# 109.9
# 甲鉄城のカバネリ
# 1132
# 0
# 8156
# 100.0
# 甲鉄城のカバネリ
# 1133
# -2000
# 2918
# 77.2
# 甲鉄城のカバネリ
# 1134
# -300
# 4621
# 97.8
# 甲鉄城のカバネリ
# 1135
# -2300
# 5968
# 87.2
# 甲鉄城のカバネリ
# 1136
# 3700
# 9107
# 113.5
# 甲鉄城のカバネリ
# 1137
# -500
# 4648
# 96.4
# 甲鉄城のカバネリ
# 1138
# 1100
# 7532
# 104.9
# 甲鉄城のカバネリ
# 1139
# 5100
# 8080
# 121.0
# 甲鉄城のカバネリ
# 1140
# -1400
# 6008
# 92.2
# バキ
# 1141
# -1400
# 3538
# 86.8
# バキ
# 1142
# -500
# 1237
# 86.5
# バキ
# 1143
# 5300
# 6000
# 129.4
# バキ
# 1144
# 0
# 0
# 0.0
# バキ
# 1145
# -900
# 694
# 56.8
# バキ
# 1146
# -300
# 2118
# 95.3
# 番長ZERO
# 1147
# 500
# 8837
# 101.9
# 番長ZERO
# 1148
# -200
# 8095
# 99.2
# 番長ZERO
# 1149
# 600
# 7931
# 102.5
# 番長ZERO
# 1150
# 3700
# 9123
# 113.5
# 番長ZERO
# 1151
# -2500
# 7987
# 89.6
# 番長ZERO
# 1152
# 1900
# 8941
# 107.1
# 番長ZERO
# 1153
# 6300
# 9971
# 121.1
# 番長ZERO
# 1154
# 6900
# 9635
# 123.9
# バイオハザード7
# 1155
# -1800
# 1918
# 68.7
# バイオハザード7
# 1156
# 2700
# 8405
# 110.7
# バキ
# 1157
# 200
# 2321
# 102.9
# バキ
# 1158
# -500
# 3962
# 95.8
# バキ
# 1159
# -700
# 546
# 57.3
# バキ
# 1160
# -1500
# 2247
# 77.7
# バキ
# 1161
# -700
# 661
# 64.7
# バキ
# 1162
# -900
# 1084
# 72.3
# 番長ZERO
# 1163
# 1200
# 6772
# 105.9
# 番長ZERO
# 1164
# 1600
# 8718
# 106.1
# 番長ZERO
# 1165
# 3700
# 9375
# 113.2
# 番長ZERO
# 1166
# 2100
# 9524
# 107.3
# 番長ZERO
# 1167
# 1600
# 8703
# 106.1
# 番長ZERO
# 1168
# 2700
# 9368
# 109.6
# 番長ZERO
# 1169
# -1400
# 9788
# 95.2
# 番長ZERO
# 1170
# 7900
# 9308
# 128.3
# バイオハザード7
# 1171
# -200
# 2239
# 97.0
# バイオハザード7
# 1172
# -2100
# 3242
# 78.4
# エリート鏡
# 1173
# -2600
# 3625
# 76.1
# エリート鏡
# 1174
# -100
# 5754
# 99.4
# エリート鏡
# 1175
# 1100
# 7420
# 104.9
# エリート鏡
# 1176
# 1600
# 6257
# 108.5
# エリート鏡
# 1177
# -800
# 4183
# 93.6
# エリート鏡
# 1178
# 2100
# 8390
# 108.3
# エリート鏡
# 1179
# -900
# 8317
# 96.4
# エリート鏡
# 1180
# -200
# 4292
# 98.4
# エリート鏡
# 1331
# 900
# 4473
# 106.7
# SアイムジャグラーEX
# 1332
# 700
# 4397
# 105.3
# SアイムジャグラーEX
# 1333
# 500
# 6721
# 102.5
# SアイムジャグラーEX
# 1334
# 600
# 4031
# 105.0
# SアイムジャグラーEX
# 1335
# -1100
# 2413
# 84.8
# SアイムジャグラーEX
# 1336
# 200
# 3388
# 102.0
# SアイムジャグラーEX
# 1337
# 0
# 3172
# 100.0
# SアイムジャグラーEX
# 1338
# 1100
# 3726
# 109.8
# SアイムジャグラーEX
# 1339
# -500
# 2137
# 92.2
# SアイムジャグラーEX
# 1340
# -900
# 3337
# 91.0
# SアイムジャグラーEX
# 1341
# 1500
# 6649
# 107.5
# SアイムジャグラーEX
# 1342
# -700
# 1181
# 80.2
# SアイムジャグラーEX
# 1343
# -1200
# 980
# 59.2
# SアイムジャグラーEX
# 1344
# -800
# 5728
# 95.3
# SアイムジャグラーEX
# 1345
# -1100
# 3004
# 87.8
# SアイムジャグラーEX
# 1346
# 1600
# 6131
# 108.7
# SアイムジャグラーEX
# 1347
# -1100
# 4415
# 91.7
# SアイムジャグラーEX
# 1348
# 1400
# 7326
# 106.4
# SアイムジャグラーEX
# 1349
# 1400
# 4506
# 110.4
# SアイムジャグラーEX
# 1350
# 0
# 1040
# 100.0
# SアイムジャグラーEX
# 1351
# 1500
# 5654
# 108.8
# SアイムジャグラーEX
# 1352
# 600
# 4539
# 104.4
# SアイムジャグラーEX
# 1353
# -2000
# 4600
# 85.5
# SアイムジャグラーEX
# 1354
# -800
# 1462
# 81.8
# SアイムジャグラーEX
# 1355
# -900
# 2705
# 88.9
# SアイムジャグラーEX
# 1356
# 1600
# 6854
# 107.8
# SアイムジャグラーEX
# 1357
# -2100
# 3369
# 79.2
# SアイムジャグラーEX
# 1358
# -1700
# 1744
# 67.5
# SアイムジャグラーEX
# 1359
# -1100
# 1628
# 77.5
# SアイムジャグラーEX
# 1360
# -1000
# 4431
# 92.5
# ハッピージャグラーVⅢ
# 1361
# -1100
# 3081
# 88.1
# ハッピージャグラーVⅢ
# 1362
# -400
# 1915
# 93.0
# ハッピージャグラーVⅢ
# 1363
# -1100
# 5850
# 93.7
# ハッピージャグラーVⅢ
# 1364
# 100
# 2399
# 101.4
# ハッピージャグラーVⅢ
# 1365
# -900
# 2173
# 86.2
# ハッピージャグラーVⅢ
# 1366
# -600
# 818
# 75.6
# ハッピージャグラーVⅢ
# 1367
# -900
# 4978
# 94.0
# ハッピージャグラーVⅢ
# 1368
# -200
# 2202
# 97.0
# ハッピージャグラーVⅢ
# 1369
# -1000
# 1144
# 70.9
# ハッピージャグラーVⅢ
# 1370
# -500
# 3189
# 94.8
# ハッピージャグラーVⅢ
# 1371
# 300
# 3978
# 102.5
# ハッピージャグラーVⅢ
# 1372
# 200
# 2208
# 103.0
# ハッピージャグラーVⅢ
# 1373
# -800
# 2113
# 87.4
# ハッピージャグラーVⅢ
# 1374
# -600
# 2925
# 93.2
# ハッピージャグラーVⅢ
# 1375
# -600
# 4081
# 95.1
# ハッピージャグラーVⅢ
# 1376
# -300
# 4492
# 97.8
# ホウオウ天翔-30
# 1377
# -600
# 1174
# 83.0
# ホウオウ天翔-30
# 1378
# -200
# 2119
# 96.9
# ホウオウ天翔-30
# 1379
# -500
# 1261
# 86.8
# ホウオウ天翔-30
# 1380
# -200
# 312
# 78.6
# ホウオウ天翔-30
# 1381
# -700
# 638
# 63.4
# ホウオウ天翔-30
# 1382
# -100
# 518
# 93.6
# ホウオウ天翔-30
# 1383
# -200
# 773
# 91.4
# ホウオウ天翔-30
# 1384
# -700
# 737
# 68.3
# ホウオウ天翔-30
# 1385
# -600
# 745
# 73.2
# ホウオウ天翔-30
# 1386
# -500
# 3321
# 95.0
# ホウオウ天翔-30
# 1387
# -100
# 1831
# 98.2
# ホウオウ天翔-30
# 1388
# -100
# 1201
# 97.2
# もっとチバリヨ-30
# 1389
# -1600
# 2188
# 75.6
# もっとチバリヨ-30
# 1390
# 300
# 1857
# 105.4
# もっとチバリヨ-30
# 1391
# -1600
# 1594
# 66.5
# もっとチバリヨ-30
# 1392
# -500
# 305
# 45.4
# もっとチバリヨ-30
# 1393
# -100
# 520
# 93.6
# もっとチバリヨ-30
# 1394
# -1900
# 1914
# 66.9
# もっとチバリヨ-30
# 1395
# -300
# 437
# 77.1
# もっとチバリヨ-30
# 1396
# 200
# 2130
# 103.1
# BIG島唄-30
# 1397
# 300
# 85
# 217.6
# BIG島唄-30
# 1398
# -100
# 33
# -1.0
# BIG島唄-30
# 1399
# -100
# 33
# -1.0
# BIG島唄-30
# 1400
# -100
# 39
# 14.5
# BIG島唄-30
# 1401
# -100
# 32
# -4.2
# BIG島唄-30
# 1402
# 0
# 32
# 100.0
# BIG島唄-30
# 1403
# -700
# 851
# 72.6
# BIG島唄-30
# 1404
# 200
# 190
# 135.1
# 沖ドキGOLD-30
# 1405
# 600
# 3636
# 105.5
# 沖ドキGOLD-30
# 1406
# -5100
# 5586
# 69.6
# 沖ドキGOLD-30
# 1407
# -800
# 4459
# 94.0
# 沖ドキGOLD-30
# 1408
# -2300
# 3786
# 79.7
# 沖ドキGOLD-30
# 1409
# 700
# 3521
# 106.6
# 沖ドキGOLD-30
# 1410
# -2300
# 5694
# 86.5
# 沖ドキGOLD-30
# 1411
# -300
# 3964
# 97.5
# 沖ドキGOLD-30
# 1412
# -1500
# 2550
# 80.4
# 沖ドキGOLD-30
# 1413
# -3400
# 3449
# 67.1
# 沖ドキGOLD-30
# 1414
# -3300
# 6637
# 83.4
# 沖ドキGOLD-30
# 1415
# 2200
# 2634
# 127.8
# 沖ドキGOLD-30
# 1416
# -900
# 4012
# 92.5
# 沖ドキGOLD-30
# 1417
# -1400
# 2286
# 79.6
# 沖ドキGOLD-30
# 1418
# 5000
# 2114
# 178.8
# 沖ドキGOLD-30
# 1419
# 400
# 3431
# 103.9
# 沖ドキGOLD-30
# 1420
# -3000
# 4707
# 78.8
# 沖ドキGOLD-30
# 1421
# 700
# 2316
# 110.1
# 沖ドキGOLD-30
# 1422
# -500
# 2811
# 94.1
# 沖ドキGOLD-30
# 1423
# -700
# 2969
# 92.1
# 沖ドキGOLD-30
# 1424
# 800
# 4753
# 105.6
# 沖ドキGOLD-30
# 1425
# 200
# 3580
# 101.9
# 沖ドキGOLD-30
# 1426
# -700
# 2585
# 91.0
# 沖ドキDUO-30
# 1427
# -900
# 1141
# 73.7
# 沖ドキDUO-30
# 1428
# 0
# 1511
# 100.0
# 沖ドキDUO-30
# 1429
# 200
# 636
# 110.5
# 沖ドキDUO-30
# 1430
# 800
# 326
# 181.8
# 沖ドキDUO-30
# 1431
# 1100
# 1108
# 133.1
# 沖ドキDUO-30
# 1432
# 2700
# 1409
# 163.9
# 沖ドキDUO-30
# 1433
# -1400
# 3511
# 86.7
# 沖ドキDUO-30
# 1434
# -200
# 919
# 92.7
# 沖ドキDUO-30
# 1435
# -800
# 1052
# 74.7
# 沖ドキDUO-30
# 1436
# 400
# 1190
# 111.2
# 沖ドキDUO-30
# 1437
# 400
# 1835
# 107.3
# 沖ドキDUO-30
# 1438
# -2200
# 2441
# 70.0
# 新ハナビ
# 1439
# -500
# 2062
# 91.9
# 新ハナビ
# 1440
# 900
# 3773
# 108.0
# 新ハナビ
# 1441
# -500
# 1370
# 87.8
# 新ハナビ
# 1442
# 1800
# 4215
# 114.2
# 新ハナビ
# 1443
# -700
# 2667
# 91.3
# 新ハナビ
# 1444
# -800
# 928
# 71.3
# バーサスリヴァイズ
# 1445
# 600
# 1671
# 112.0
# バーサスリヴァイズ
# 1446
# -200
# 1165
# 94.3
# バーサスリヴァイズ
# 1447
# -700
# 1025
# 77.2
# バーサスリヴァイズ
# 1448
# -500
# 1451
# 88.5
# 花火絶景
# 1449
# -1200
# 3498
# 88.6
# 花火絶景
# 1450
# -700
# 2102
# 88.9
# 花火絶景
# 1451
# -200
# 567
# 88.2
# 花火絶景
# 1452
# 1200
# 1366
# 129.3
# 花火絶景
# 1453
# -300
# 268
# 62.7
# ハードボイルド
# 1454
# -800
# 2860
# 90.7
# ハードボイルド
# 1455
# -2300
# 2940
# 73.9
# ハードボイルド
# 1456
# 600
# 3227
# 106.2
# ニューゲッターマウス
# 1457
# -300
# 1280
# 92.2
# ニューゲッターマウス
# 1458
# 2600
# 5526
# 115.7
# ディスクアップ2
# 1459
# 200
# 6734
# 101.0
# ディスクアップ2
# 1460
# -600
# 7726
# 97.4
# マッピー
# 1461
# -1000
# 4927
# 93.2
# {'spreadsheetId': '1LmkbYAJq2g684bjF-vumexLgKrFQNsF-dhsdTv33_Yk',
#  'updatedRange': "'20230213_スーパーDステーション飯塚店'!A1:E444",
#  'updatedRows': 444,
#  'updatedColumns': 5,
#  'updatedCells': 2220}

# %%
#選択　並びピックアップ用

pd.set_option('display.max_rows', 8)
worksheet_df = pd.DataFrame(worksheet.get_all_values())
worksheet_df = worksheet_df.rename(columns={0: '機種', 1: '台番', 2: '差枚', 3: 'G数', 4: '出率', 5: '対象'})
#display(worksheet_df)

#ここに6台並びと思われる最初の台番号をいれる
pickup_df_text = ''
u = worksheet_df['対象'].unique()
for target_num in worksheet_df['対象'].unique():
    if target_num == '':
        print('continue')
        continue
    df_b = worksheet_df.query('対象.str.contains(@target_num)', engine='python')
    df_b = df_b.drop("対象", axis=1)
    display(df_b)
    print(df_b.to_html(justify='justify-all',index=False))

    pickup_df_text += df_b.to_html(justify='justify-all',index=False)
    
pickup_text = '<h2>注目ピックアップ</h2>\n[st-kaiwa1]今回の並びでよかった場所[/st-kaiwa1]'
pickup_text_2 = '\n[st-kaiwa1]今回の並びの一言コメントを記入[/st-kaiwa1]'
#print(narabi_kisyu_df_text)

# %%
#html出力用

title_text_only.split('_')[1]
title_text_only.split('_')[0]
from datetime import datetime as dt

tstr = title_text_only.split('_')[0]
tdatetime = dt.strptime(tstr, '%Y%m%d')
month = tdatetime.strftime('%m').lstrip('0')
day = tdatetime.strftime('%d').lstrip('0')
date_str = month + '/' + day 
date_str

import requests
from bs4 import BeautifulSoup

#タイトル部分の出力

title_text_only
tenpo_name = title_text_only.split('_')[1]
day_number = title_text_only.split('_')[0][-1]
title = '<h2>' + date_str + ' ' + tenpo_name + '</h2>'


day_number = day_number.replace('(月','').replace('(火','').replace('(水','').replace('(木','').replace('(金','').replace('(土','').replace('(日','')

day_number

#print(title)

tenpo_ave_gamesuu = int(sheet_df['G数'].sum() / len(sheet_df['G数']))
tenpo_ave_gamesuu = str("{:,}".format(tenpo_ave_gamesuu)) + 'G'
tenpo_ave_samai = str(int(sheet_df['差枚'].sum() / len(sheet_df['G数']))) + '枚'
tenpo_sousamai = sheet_df['差枚'].sum()
tenpo_sousamai = str("{:,}".format(tenpo_sousamai )) + '枚'

win_rate_bunshi = 0
for x in list(sheet_df['差枚']):
    if x > 0:
        win_rate_bunshi += 1
    else:
        pass
win_rate = str(win_rate_bunshi)+'/'+str(len(sheet_df['G数']))

#概要部分の出力
day_number = title_text_only.split('_')[0][-1]
tenpo_gaiyou_dict = {'状況': ['総差枚', '平均差枚', '平均G数', '勝率'], f'旧イベント日（{day_number}のつく日）':[tenpo_sousamai,tenpo_ave_samai, tenpo_ave_gamesuu, win_rate]}

matome_df = pd.DataFrame.from_dict(tenpo_gaiyou_dict)

kisyu_matome_df = kisyubetu_sheet_df



gaiyou_matome = matome_df.to_html(justify='justify-all',index=False)
#print(gaiyou_matome)

#機種の全台データ一覧
#print(ichiran_df.to_html(justify='justify-all',index=False))
text = ichiran_df.to_html(justify='justify-all',index=False)
completed_text ='[su_spoiler title="全台データ一覧" style="fancy" icon="chevron-circle" anchor="Hello"]' + text + '[/su_spoiler]'

#差枚G数グラフ一覧
#kisyu_matome_df = pd.read_html(url)[1]

horaizontal_bar_graph = """<script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/2.1.4/Chart.min.js"></script>
<canvas id="myChart" height="1500" style="padding: 0px 10px 0px 10px;"></canvas>
<script>
var ctx = document.getElementById("myChart").getContext('2d');
var myChart = new Chart(ctx, {
  type: 'horizontalBar',
  data:  {
    labels:""" + str(kisyu_matome_df['機種'].to_list()) + """,
    datasets: [{
        label: "平均差枚",
        data:""" + str(kisyu_matome_df['差枚'].to_list()) +""",
        borderColor: "rgb(255, 99, 132)",
        backgroundColor: "red"
      },{
        label: "平均G数",
        data:""" + str(kisyu_matome_df['G数'].to_list()) + """,
backgroundColor: "blue"
    }
]
  }
});
</script>"""
#print(horaizontal_bar_graph)

kisyu_matome_text = ''
#機種別テーブル
#kisyu_matome_df = pd.read_html(url)[1]

for kisyu_name in kisyu_matome_df['機種']:
    target_matome_kisyu = kisyu_matome_df.query(f'機種.str.contains("{kisyu_name}")', engine='python')
    try:
        kisyu_text = f'{str(target_matome_kisyu.iloc[0,0])}<br> 平均差枚:{str(target_matome_kisyu.iloc[0,1])}枚<br> 平均G数:{str(target_matome_kisyu.iloc[0,2])}G<br>  勝率:{str(target_matome_kisyu.iloc[0,3])}'
    except:
        continue
    kisyu_matome_text += '[su_spoiler title="' + kisyu_text + '" style="fancy" icon="chevron-circle" anchor="Hello"]'
    #print('[su_spoiler title="',kisyu_text,'" style="fancy" icon="chevron-circle"]')
    
    target_kisyu = ichiran_df.query(f'機種.str.contains("{kisyu_name}")', engine='python')
    target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
    target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
    kisyu_matome_text += target_kisyu.to_html(justify='justify-all',index=False) + '\n'
    #print(target_kisyu.to_html(justify='justify-all',index=False))
    
    kisyu_matome_text += '[/su_spoiler]' + '\n'
    #print('[/su_spoiler]')


zizen_text = '\n<h2>事前情報</h2>\n画像を入れてください\n[st-kaiwa1]一言コメント部分[/st-kaiwa1]'

full_text  = (title + '\n' + gaiyou_matome + zizen_text + '<h2>機種別平均差枚&平均G数グラフ</h2>'+ horaizontal_bar_graph +  pickup_text + pickup_df_text + pickup_text_2 + "<h2>全台データ一覧</h2>※タップで一覧が開きます"+ completed_text + '<h2>機種別データ一覧</h2>※機種タップで各台データが見れます' + kisyu_matome_text)
print('準備完了')
# Out:
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# 準備完了
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'
# <ipython-input-7-67d3a6053263>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['差枚'] = target_kisyu['差枚'].astype(str) + '枚'
# <ipython-input-7-67d3a6053263>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_kisyu['G数'] = target_kisyu['G数'].astype(str) + 'G'

# %%
# -*- coding: utf-8 -*-

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import time
from datetime import datetime
from wordpress_xmlrpc import Client, WordPressPost
from wordpress_xmlrpc.methods.users import GetUserInfo
from wordpress_xmlrpc.methods.posts import GetPosts, NewPost
def main():
    """
    変数を定義
    """
    id = "admin"
    password="slopachi777"
    #idとpasswordはwordpressの管理画面に入るためのもの

    url="https://kansai-sloeve.com/xmlrpc.php"
    #第3者が閲覧するURLの後ろに/xmlrpc.phpをつける。
    #ワードプレスの管理画面の後ろにつけるとエラーになった

    which="draft"
    #which="draft"
    #下書きに投稿するか本番で投稿するか選択
    """
    クライアントの呼び出しなど
    """

    wp = Client(url, id,password)
    post = WordPressPost()

    """
    実際に投稿する
    """

    post.post_status = which
    post.title = date_str +' '+tenpo_name + '結果まとめ'
    post.content = full_text
    post.terms_names = {
    "post_tag": [f'{day_number}のつく日',tenpo_name,prefecture],
    "category": ['結果記事'],
    }
    #過去に投稿した記事としたい場合、投稿日をここで指定。例として2018年1月1日10時5分10秒に投稿した例を示す。
    #post.date=datetime.strptime("2018/1/01 10:05:10","%Y/%m/%d %H:%M:%S")
    wp.call(NewPost(post))

main()
#ここまでで下書きに記事完成
